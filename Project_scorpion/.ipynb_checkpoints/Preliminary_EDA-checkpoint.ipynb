# %% [markdown]
# # Contract notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline

# %%
df = pd.read_excel('../_Data/DHS 2017 and 2018 Raw Data.xlsx')
df.head()
# Out:
#        award_id_piid modification_number  transaction_number  \
# 0  70B03C18P00000722                   0                 0.0
# 1  70FB7018F00000266                   0                 0.0
# 2  70FB7018F00000270                   0                 0.0
# 3      HSFE7017J0257                   0                 0.0
# 4      HSFE7017J0257              P00001                 0.0
#
#    parent_award_agency_id             parent_award_agency_name  \
# 0                     NaN                                  NaN
# 1                  7022.0  FEDERAL EMERGENCY MANAGEMENT AGENCY
# 2                  7022.0  FEDERAL EMERGENCY MANAGEMENT AGENCY
# 3                  7022.0  FEDERAL EMERGENCY MANAGEMENT AGENCY
# 4                  7022.0  FEDERAL EMERGENCY MANAGEMENT AGENCY
#
#      parent_award_id                                    Work Contract Vehicle  \
# 0  70B03C18P00000722  All Other Contracts Under $2M Annually              NaN
# ...

# %%
df.tail()
# Out:
#        award_id_piid modification_number  transaction_number  \
# 7487  HSCEMD16J00010              P00005                 0.0
# 7488  HSCEMD16J00010              P00009                 0.0
# 7489   HSFE3014J0311              P00003                 0.0
# 7490   HSFE3014J0311              P00004                 0.0
# 7491   HSFE3017J0184                   0                 0.0
#
#       parent_award_agency_id             parent_award_agency_name  \
# 7487                  7001.0     OFFICE OF PROCUREMENT OPERATIONS
# 7488                  7001.0     OFFICE OF PROCUREMENT OPERATIONS
# 7489                  7022.0  FEDERAL EMERGENCY MANAGEMENT AGENCY
# 7490                  7022.0  FEDERAL EMERGENCY MANAGEMENT AGENCY
# 7491                  7022.0  FEDERAL EMERGENCY MANAGEMENT AGENCY
#
#      parent_award_id                                    Work Contract Vehicle  \
# 7487  HSHQDC13DE2029  All Other Contracts Under $2M Annually              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7492 entries, 0 to 7491
# Columns: 266 entries, award_id_piid to last_modified_date
# dtypes: datetime64[ns](6), float64(20), int64(8), object(232)
# memory usage: 15.2+ MB

# %%
df.head().transpose()
# Out:
#                                                                                          0  \
# award_id_piid                                                            70B03C18P00000722
# modification_number                                                                      0
# transaction_number                                                                       0
# parent_award_agency_id                                                                 NaN
# parent_award_agency_name                                                               NaN
# parent_award_id                                                          70B03C18P00000722
# Work                                                All Other Contracts Under $2M Annually
# Contract Vehicle                                                                       NaN
# Completion Date                                                                        NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.distplot(df.annual_revenue.dropna())
# Out:
# F:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig, ax = plt.subplots(figsize=(16, 9))
sns.scatterplot(x='number_of_employees', y='annual_revenue', data=df, ax=ax)

# %%
df.awarding_agency_name.value_counts()
# Out:
# DEPARTMENT OF HOMELAND SECURITY (DHS)            7297
# GENERAL SERVICES ADMINISTRATION (GSA)             186
# DEPARTMENT OF THE INTERIOR (DOI)                    6
# DEPARTMENT OF DEFENSE (DOD)                         2
# DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)       1
# Name: awarding_agency_name, dtype: int64

# %%
df.awarding_agency_code.value_counts()
# Out:
# 70    7297
# 47     186
# 14       6
# 97       2
# 75       1
# Name: awarding_agency_code, dtype: int64

# %%
df.columns
# Out:
# Index(['award_id_piid', 'modification_number', 'transaction_number',
#        'parent_award_agency_id', 'parent_award_agency_name', 'parent_award_id',
#        'Work', 'Contract Vehicle', 'Completion Date', 'Completion Year',
#        ...
#        'native_hawaiian_servicing_institution', 'school_of_forestry',
#        'veterinary_college', 'dot_certified_disadvantage',
#        'self_certified_small_disadvantaged_business',
#        'small_disadvantaged_business', 'c8a_program_participant',
#        'historically_underutilized_business_zone_hubzone_firm',
#        'sba_certified_8a_joint_venture', 'last_modified_date'],
#       dtype='object', length=266)

# %%
df['number_of_employees'].hist()
