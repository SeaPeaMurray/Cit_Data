# %% [markdown]
# # Notebook for USASpending files
#
# ### This notebook will provide the steps for a pipeline script in Python to handle data

# %%
'''Turn f and t into booleans
Concat contract vehicles
Other concat in java folder'''
# Out:
# 'Turn f and t into booleans\nConcat contract vehicles\nOther concat in java folder'

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import re
import datetime

# Create small data set to pull date-parsing column names
df = pd.read_csv('_Data/TREAS/api_bulk_listmonthlyfiles/2015_020_Contracts_Full_20181212_1.csv').head()

# Extract date column names with regular expression
date_list = [col for col in df if re.search(r'date\b', col) is not None]

# Build full dataframe with parsed dates
df = pd.read_csv('_Data/TREAS/api_bulk_listmonthlyfiles/2015_020_Contracts_Full_20181212_1.csv',
                 parse_dates=date_list, infer_datetime_format=True)

# Parse the dates of problematic column: period_of_performance_start_date
df.loc[:, 'period_of_performance_start_date'] = pd.to_datetime(
    df['period_of_performance_start_date'], errors='coerce')

# Forward fill NaN values in parent_award_id with award_id_piid values
df.loc[:, 'parent_award_id'] = df['parent_award_id'].fillna(df['award_id_piid'])

# Create dataframes of vehicle and work
vehicle = pd.read_csv('_Data/TREAS/ContractVehicles.csv', 
                      names=['parent_award_id', 'contract_vehicle'])
work = pd.read_csv('_Data/TREAS/Work.csv')
work.columns = ['parent_award_id', 'award_id_piid', 'work']

# Join vehicle and work to file
df_new = df.merge(vehicle, on='parent_award_id')
df_new = pd.merge(df, work, on=['parent_award_id', 'award_id_piid'], how='left')

# %%
work
# Out:
#       parent_award_id   award_id_piid  \
# 0      2031JW18P00016  2031JW18P00016
# 1      2031JW18P00043  2031JW18P00043
# 2      2031ZA17C00080  2031ZA17C00080
# 3      2032H318C00010  2032H318C00010
# 4      2032H518C00036  2032H518C00036
# 5      2032H518C00045  2032H518C00045
# 6      2032H518C00056  2032H518C00056
# 7      2032H518C00065  2032H518C00065
# 8      2032H518C00072  2032H518C00072
# 9      2032H518C00082  2032H518C00082
# 10     2032H518C00091  2032H518C00091
# 11     2032H518C00110  2032H518C00110
# 12     2032H518D00007  2032H518F00105
# 13     2032H518D00019  2032H518F00916
# 14     2032H518D00023  2032H518D00023
# 15     2032H518P00013  2032H518P00013
# 16     2032H518P00023  2032H518P00023
# 17     2032H518P00141  2032H518P00141
# 18     2032H518P00184  2032H518P00184
# 19     2032H518P00209  2032H518P00209
# 20     2032H518P00214  2032H518P00214
# 21     2032H518P00223  2032H518P00223
# 22     2032H518P00224  2032H518P00224
# 23     2032H518P00240  2032H518P00240
# 24     2032H518P00248  2032H518P00248
# 25     2032H518P00263  2032H518P00263
# 26     2032H518P00276  2032H518P00276
# 27     2032H518P00294  2032H518P00294
# 28     2032H518P00300  2032H518P00300
# 29     2032H518P00318  2032H518P00318
# ...               ...             ...
# 1649       TOS11D0012               7
# 1650       TOS11D0012               8
# 1651       TOS11D0012  TOS11D00120002
# 1652       TOS11D0012  TOS11D00120003
# 1653       TOS11D0012  TOS11D00120004
# 1654       TOS11D0012  TOS11D00120005
# 1655       TOS11D0012  TOS11D00120007
# 1656       TOS12D0002               7
# 1657       TOS12D0002  TOS12D00020006
# 1658       TOS17F0008      TOS17F0008
# 1659       TOS17F0014      TOS17F0014
# 1660    TOSFIT12F0001   TOSFIT12F0001
# 1661    TOSOFR14D0007          140001
# 1662    TOSOFR14D0007          160002
# 1663    TOSOFR15D0001          150001
# 1664    TOSOFR15D0001          160002
# 1665    TOSOFR15D0001          160003
# 1666    TOSOFR15D0001          170004
# 1667    TOSOFR16C0001   TOSOFR16C0001
# 1668   TOSOFR16C0001A  TOSOFR16C0001A
# 1669  TPDARCBPA120002              21
# 1670  TPDARCBPA120002              23
# 1671  TPDARCBPA120002              26
# 1672  TPDARCBPA120002              27
# 1673  TPDARCBPA120002              28
# 1674  TPDARCBPA120002              29
# 1675    TPDTTB09C0009   TPDTTB09C0009
# 1676    TPDTTB12C0008          170004
# 1677    TPDTTB12C0008          170005
# 1678    W91QUZ07D0005     TDOX11C0002
#
#                                                    work
# 0                All Other Contracts Under $2M Annually
# 1                All Other Contracts Under $2M Annually
# 2                All Other Contracts Under $2M Annually
# 3                Internal Control and Oversight Support
# 4     Project Planning, Investment, and Governance (...
# 5                All Other Contracts Under $2M Annually
# 6                All Other Contracts Under $2M Annually
# 7                All Other Contracts Under $2M Annually
# 8        Corporate Data Domain Data Services IT Support
# 9                All Other Contracts Under $2M Annually
# 10               All Other Contracts Under $2M Annually
# 11                          Intranet SharePoint Rebuild
# 12                      Large Case Tax Engine Audit BPA
# 13               All Other Contracts Under $2M Annually
# 14               All Other Contracts Under $2M Annually
# 15               All Other Contracts Under $2M Annually
# 16               All Other Contracts Under $2M Annually
# 17               All Other Contracts Under $2M Annually
# 18               All Other Contracts Under $2M Annually
# 19                             Unknown Insysco Contract
# 20               All Other Contracts Under $2M Annually
# 21               All Other Contracts Under $2M Annually
# 22               All Other Contracts Under $2M Annually
# 23               All Other Contracts Under $2M Annually
# 24               All Other Contracts Under $2M Annually
# 25               All Other Contracts Under $2M Annually
# 26               All Other Contracts Under $2M Annually
# 27               All Other Contracts Under $2M Annually
# 28               All Other Contracts Under $2M Annually
# 29               All Other Contracts Under $2M Annually
# ...                                                 ...
# 1649             All Other Contracts Under $2M Annually
# 1650             All Other Contracts Under $2M Annually
# 1651             All Other Contracts Under $2M Annually
# 1652             All Other Contracts Under $2M Annually
# 1653             All Other Contracts Under $2M Annually
# 1654             All Other Contracts Under $2M Annually
# 1655             All Other Contracts Under $2M Annually
# 1656      Professional Money Laundering Network Support
# 1657      Professional Money Laundering Network Support
# 1658             All Other Contracts Under $2M Annually
# 1659             All Other Contracts Under $2M Annually
# 1660             All Other Contracts Under $2M Annually
# 1661             All Other Contracts Under $2M Annually
# 1662             All Other Contracts Under $2M Annually
# 1663             All Other Contracts Under $2M Annually
# 1664             All Other Contracts Under $2M Annually
# 1665             All Other Contracts Under $2M Annually
# 1666             All Other Contracts Under $2M Annually
# 1667             All Other Contracts Under $2M Annually
# 1668             All Other Contracts Under $2M Annually
# 1669             All Other Contracts Under $2M Annually
# 1670             All Other Contracts Under $2M Annually
# 1671             All Other Contracts Under $2M Annually
# 1672             All Other Contracts Under $2M Annually
# 1673             All Other Contracts Under $2M Annually
# 1674             All Other Contracts Under $2M Annually
# 1675             All Other Contracts Under $2M Annually
# 1676             All Other Contracts Under $2M Annually
# 1677             All Other Contracts Under $2M Annually
# 1678             All Other Contracts Under $2M Annually
#
# [1679 rows x 3 columns]

# %%
for col in df:
    if len(df[col].unique()) == 2:
        if df[col].unique() != ['f', 't'] and df[col].unique() != ['t', 'f']:
            print('{} \n\n'.format(col), df[col].unique())
        
['f', 't']
['t', 'f']
['N', 'Y']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-0a84272d72e2> in <module>
#       1 for col in df:
#       2     if len(df[col].unique()) == 2:
# ----> 3         if df[col].unique() != ['f', 't'] and df[col].unique() != ['t', 'f']:
#       4             print('{} \n\n'.format(col), df[col].unique())
#       5
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
df['tribally_owned_business'].unique() == ['f', 't']
# Out:
# array([ True,  True])

# %%
df['contract_bundling_code'].value_counts()
# Out:
# D    2621
# Name: contract_bundling_code, dtype: int64

# %%
len(df['contract_bundling_code'])
# Out:
# 2626
